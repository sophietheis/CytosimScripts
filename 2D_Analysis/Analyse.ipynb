# %%
# Changement dossier de travail
#setwd ("~/Documents/ResultatsCytosim/oscillations/Exploration2/simul_osci/metaphase1kt_97MTseuil_20cohesinStiffness_80KTMTstiffness/run2/")
#setwd ("~/Documents/ResultatsCytosim/oscillations/SansNormalisation/res/metaphase1kt_100MTseuil_20cohesinStiffness_80KTMTstiffness/run10/")
#setwd ("~/Documents/test/metaphase2/run1/")

# %%
#setwd ("~/Documents/GIT/cytosim/cytosim-public.5042/oscillation/metaphase1kt_100MTseuil_20cohesinStiffness_80KTMTstiffness/run2")
#setwd ("~/Documents/ResultatsCytosim/oscillations/proba_asymetrique/res/metaphase1kt_100MTseuil_20cohesinStiffness_160KTMTstiffness/run4/")
#setwd ("/media/sophie/Sophie/Resultats_simulations/oscillations/proba_asymetrique/res/metaphase1kt_100MTseuil_20cohesinStiffness_140KTMTstiffness/run11")
setwd("/media/sophie/Sophie_Cytosim/simulation/simulation/0800_1600_075_250_100_090/run1")

# Lecture des datas
data_solid = read.table("solid.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE)
#data_crosslinker_left = read.table("couple:KTMT.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE)
#data_crosslinker_right = read.table("couple:KTMT2.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE)

data_fiber_left  = read.table("fiber:microtubule_kinetochore_spb1.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE, fill=TRUE)
data_fiber_right = read.table("fiber:microtubule_kinetochore_spb2.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE,fill=TRUE)

#data_ktmt_left  = read.table("couple:KTMT.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE, fill=TRUE)
#data_ktmt_right = read.table("couple:KTMT2.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE, fill=TRUE)

#data_klp9 = read.table("couple:klp9.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE)
#data_ase1 = read.table("couple:ASE1.txt", head = TRUE, dec = '.', stringsAsFactors = FALSE)

x_spb_left  = data_solid$x
y_spb_left  = data_solid$y
x_spb_right = data_solid$x.1
y_spb_right = data_solid$y.1

t0=250/0.05
t1=300/0.05

#png("../../../Figures/97MTseuil20KTMT10run.png", width = 1000, height = 500)
plot (data_solid$time[t0:t1], data_solid$x[t0:t1],type='l', ylim=c(-1,1), xlab="Temps(s)", ylab="Position(µm)")
lines (data_solid$time[t0:t1],data_solid$x.1[t0:t1])
#lines (data_solid$time[t0:t1],data_solid$x.1[t0:t1]-0.1)
#lines (data_solid$time[t0:t1],data_solid$x[t0:t1]+0.1)
lines (data_solid$time[t0:t1],data_solid$x.2[t0:t1], col="red")
lines (data_solid$time[t0:t1],data_solid$x.3[t0:t1], col="red")
lines (data_solid$time[t0:t1],data_solid$x[t0:t1]-(data_solid$x[t0:t1]-data_solid$x.1[t0:t1])/2, col = "gray")
lines (data_solid$time[t0:t1],(data_solid$x.2[t0:t1]+data_solid$x.3[t0:t1])/2, col="purple")
#dev.off()
# Out:
# plot without title

# %%
# Calcul de la distance MTseuil
dist_spb_kt_left  = sqrt((data_solid$x - data_solid$x.2)^2 + (data_solid$y - data_solid$y.2)^2)
dist_spb_kt_right = sqrt((data_solid$x.1 - data_solid$x.3)^2 + (data_solid$y.1 - data_solid$y.3)^2)

# %%
#png("../../../Figures/97MTseuil20KTMT10run_dist.png", width = 1000, height = 500)
plot (data_solid$time, dist_spb_kt_left, type = 'l', ylim=c(0,2), col='red')
lines (data_solid$time,dist_spb_kt_right, col="blue")
lines(data_solid$time, dist_spb_kt_right+dist_spb_kt_left, col="black")
lines(data_solid$time, (dist_spb_kt_right+dist_spb_kt_left)/2, col="gray")
lines(data_solid$time, sqrt((data_solid$x.1 - data_solid$x)^2 + (data_solid$y.1 - data_solid$y)^2), col="pink")

#dev.off()
# Out:
# plot without title

# %%
# Calcul de la taille des fibres
x_start_fiber_left = data_fiber_left[seq(4, 25, 6)]
x_end_fiber_left   = data_fiber_left[seq(6, 25, 6)]
y_start_fiber_left = data_fiber_left[seq(5, 25, 6)]
y_end_fiber_left   = data_fiber_left[seq(7, 25, 6)]

x_start_fiber_right = data_fiber_right[seq(4, 25, 6)]
x_end_fiber_right   = data_fiber_right[seq(6, 25, 6)]
y_start_fiber_right = data_fiber_right[seq(5, 25, 6)]
y_end_fiber_right   = data_fiber_right[seq(7, 25, 6)]

#size_fibres_left  = (sqrt((data_fiber_left[x_end_fiber]-data_fiber_left[x_start_fiber])^2+(data_fiber_left[y_start_fiber]-data_fiber_left[y_end_fiber])^2))
#size_fibres_rigth = (sqrt((data_fiber_right[x_end_fiber]-data_fiber_right[x_start_fiber])^2+(data_fiber_right[y_start_fiber]-data_fiber_right[y_end_fiber])^2))


size_fibres_left_1 = sqrt((x_start_fiber_left$x - x_end_fiber_left$x.1)^2 + (y_start_fiber_left$y - y_end_fiber_left$y.1)^2)
size_fibres_left_2 = sqrt((x_start_fiber_left$x.2 - x_end_fiber_left$x.3)^2 + (y_start_fiber_left$y.2 - y_end_fiber_left$y.3)^2)
size_fibres_left_3 = sqrt((x_start_fiber_left$x.4 - x_end_fiber_left$x.5)^2 + (y_start_fiber_left$y.4 - y_end_fiber_left$y.5)^2)
size_fibres_left_4 = sqrt((x_start_fiber_left$x.6 - x_end_fiber_left$x.7)^2 + (y_start_fiber_left$y.6 - y_end_fiber_left$y.7)^2)


size_fibres_right_1 = sqrt((x_start_fiber_right$x - x_end_fiber_right$x.1)^2 + (y_start_fiber_right$y - y_end_fiber_right$y.1)^2)
size_fibres_right_2 = sqrt((x_start_fiber_right$x.2 - x_end_fiber_right$x.3)^2 + (y_start_fiber_right$y.2 - y_end_fiber_right$y.3)^2)
size_fibres_right_3 = sqrt((x_start_fiber_right$x.4 - x_end_fiber_right$x.5)^2 + (y_start_fiber_right$y.4 - y_end_fiber_right$y.5)^2)
size_fibres_right_4 = sqrt((x_start_fiber_right$x.6 - x_end_fiber_right$x.7)^2 + (y_start_fiber_right$y.6 - y_end_fiber_right$y.7)^2)


# Remplacement des NA par 0
# size_fibres_left  = replace(size_fibres_left,  is.na(size_fibres_left),0)
# size_fibres_rigth = replace(size_fibres_rigth, is.na(size_fibres_rigth),0)

# %%
size_fibres_left_1  = replace(size_fibres_left_1,  is.na(size_fibres_left_1),0)
size_fibres_right_1 = replace(size_fibres_right_1, is.na(size_fibres_right_1),0)
size_fibres_left_2 = replace(size_fibres_left_2,  is.na(size_fibres_left_2),0)
size_fibres_right_2 = replace(size_fibres_right_2, is.na(size_fibres_right_2),0)
size_fibres_left_3 = replace(size_fibres_left_3,  is.na(size_fibres_left_3),0)
size_fibres_right_3 = replace(size_fibres_right_3, is.na(size_fibres_right_3),0)
size_fibres_left_4 = replace(size_fibres_left_4,  is.na(size_fibres_left_4),0)
size_fibres_right_4 = replace(size_fibres_right_4, is.na(size_fibres_right_4),0)

# %%
### Etat des MT de gauche par rapport à ceux de droite
diff_fibre_left_1 = size_fibres_left_1 [2:(length(size_fibres_left_1))] - size_fibres_left_1[1:(length(size_fibres_left_1)-1)] 
diff_fibre_left_2 = size_fibres_left_2 [2:(length(size_fibres_left_2))] - size_fibres_left_2[1:(length(size_fibres_left_2)-1)] 
diff_fibre_left_3 = size_fibres_left_3 [2:(length(size_fibres_left_3))] - size_fibres_left_3[1:(length(size_fibres_left_3)-1)] 
diff_fibre_left_4 = size_fibres_left_4 [2:(length(size_fibres_left_4))] - size_fibres_left_4[1:(length(size_fibres_left_4)-1)] 

diff_fibre_left_1[which(diff_fibre_left_1>0)] = 1
diff_fibre_left_1[which(diff_fibre_left_1<0)] = 0
diff_fibre_left_2[which(diff_fibre_left_2>0)] = 1
diff_fibre_left_2[which(diff_fibre_left_2<0)] = 0
diff_fibre_left_3[which(diff_fibre_left_3>0)] = 1
diff_fibre_left_3[which(diff_fibre_left_3<0)] = 0
diff_fibre_left_4[which(diff_fibre_left_4>0)] = 1
diff_fibre_left_4[which(diff_fibre_left_4<0)] = 0

nb_fibres_left_poly = diff_fibre_left_1+diff_fibre_left_2+diff_fibre_left_3+diff_fibre_left_4

diff_fibre_right_1 = size_fibres_right_1 [2:(length(size_fibres_right_1))] - size_fibres_right_1[1:(length(size_fibres_right_1)-1)] 
diff_fibre_right_2 = size_fibres_right_2 [2:(length(size_fibres_right_2))] - size_fibres_right_2[1:(length(size_fibres_right_2)-1)] 
diff_fibre_right_3 = size_fibres_right_3 [2:(length(size_fibres_right_3))] - size_fibres_right_3[1:(length(size_fibres_right_3)-1)] 
diff_fibre_right_4 = size_fibres_right_4 [2:(length(size_fibres_right_4))] - size_fibres_right_4[1:(length(size_fibres_right_4)-1)]


diff_fibre_right_1[which(diff_fibre_right_1>0)] = 1
diff_fibre_right_1[which(diff_fibre_right_1<0)] = 0
diff_fibre_right_2[which(diff_fibre_right_2>0)] = 1
diff_fibre_right_2[which(diff_fibre_right_2<0)] = 0
diff_fibre_right_3[which(diff_fibre_right_3>0)] = 1
diff_fibre_right_3[which(diff_fibre_right_3<0)] = 0
diff_fibre_right_4[which(diff_fibre_right_4>0)] = 1
diff_fibre_right_4[which(diff_fibre_right_4<0)] = 0

nb_fibres_right_poly = diff_fibre_right_1+diff_fibre_right_2+diff_fibre_right_3+diff_fibre_right_4

t0 = 550/0.05
t1 = 750/0.05
#t0 = 500
#t1 = 1000
#png("/media/sophie/Sophie/Resultats_simulations/oscillations/proba_asymetrique/res/run11_330_350.png", width = 1000, height = 500)
par(mfrow=c(2,1))
plot (data_solid$time[t0:t1], data_solid$x[t0:t1],type='l', ylim=c(-0.8,0.7), xlab="Time(s)", ylab="Position(µm)")
lines (data_solid$time[t0:t1],data_solid$x.1[t0:t1])
lines (data_solid$time[t0:t1],data_solid$x.2[t0:t1], col="red")
lines (data_solid$time[t0:t1],data_solid$x.3[t0:t1], col="blue")
lines (data_solid$time[t0:t1],data_solid$x[t0:t1]-(data_solid$x[t0:t1]-data_solid$x.1[t0:t1])/2, col = "gray")
lines (data_solid$time[t0:t1],(data_solid$x.2[t0:t1]+data_solid$x.3[t0:t1])/2, col="purple")
plot (data_solid$time[t0:t1],nb_fibres_left_poly[t0:t1], type='l', col="red", ylim=c(0,4), xlab="Time(s)", ylab="Nb polymerising MT")
lines(data_solid$time[t0:t1],nb_fibres_right_poly[t0:t1], col= "blue")
#dev.off()
#plot (data_solid$time[t0:t1],nb_fibres_left_poly[t0:t1], type='b',pch=3, col="red", ylim=c(0,4))
#lines(data_solid$time[t0:t1],nb_fibres_right_poly[t0:t1],  type='b',pch=3,col= "blue")
#plot (data_solid$time[t0:t1], data_ktmt_left$force[t0:t1], type = 'b', col = "red")
#lines(data_solid$time[t0:t1], data_ktmt_right$force[t0:t1], type = 'b', col = "blue")
# Out:
# plot without title

# %%
t0 = 700/0.05
t1 = 720/0.05

#png("/media/sophie/Sophie/Resultats_simulations/oscillations/proba_asymetrique/res/run11_mt_330_350.png", width = 1000, height = 500)
#par(mfrow=c(2,1))
plot (data_solid$time[t0:t1],data_solid$x.1[t0:t1]-(dist_spb_kt_right[t0:t1]-0.15)+0.028, col="blue", type = 'l',ylim=c(-1,1), xlab="Time(s)", ylab="MT size(µm)")
lines(data_solid$time[t0:t1],data_solid$x.1[t0:t1]-(dist_spb_kt_right[t0:t1]-0.15)-0.014, col = "blue")
lines(data_solid$time[t0:t1], data_solid$x.1[t0:t1]-size_fibres_right_1[t0:t1], col = "pink")
lines(data_solid$time[t0:t1], data_solid$x.1[t0:t1]-size_fibres_right_2[t0:t1], col = "purple")
lines(data_solid$time[t0:t1], data_solid$x.1[t0:t1]-size_fibres_right_3[t0:t1], col = "green")
lines(data_solid$time[t0:t1], data_solid$x.1[t0:t1]-size_fibres_right_4[t0:t1], col = "black")
lines(data_solid$time[t0:t1], data_solid$x.1[t0:t1]-rep(0.1,t1-t0+1), col="gray")

lines(data_solid$time[t0:t1],data_solid$x[t0:t1]+(dist_spb_kt_left[t0:t1]-0.15)+0.014, col="red", type = 'l' )
lines(data_solid$time[t0:t1],data_solid$x[t0:t1]+(dist_spb_kt_left[t0:t1]-0.15)-0.028, col = "red")
lines(data_solid$time[t0:t1], data_solid$x[t0:t1]+size_fibres_left_1[t0:t1], col = "pink", type='l')
lines(data_solid$time[t0:t1], data_solid$x[t0:t1]+size_fibres_left_2[t0:t1], col = "purple", type='l')
lines(data_solid$time[t0:t1], data_solid$x[t0:t1]+size_fibres_left_3[t0:t1], col = "green", type='l')
lines(data_solid$time[t0:t1], data_solid$x[t0:t1]+size_fibres_left_4[t0:t1], col = "black", type='l')
lines(data_solid$time[t0:t1], data_solid$x[t0:t1]+rep(0.1,t1-t0+1), col="gray")
dev.off()
#dist_kt_kt  = sqrt((data_solid$x.3 - data_solid$x.2)^2 + (data_solid$y.3 - data_solid$y.2)^2)
#plot (data_solid$time[t0:t1], dist_kt_kt[t0:t1], type='b', pch=3)
# Out:
# null device
#           1
# plot without title

# %%
par(mfrow=c(2,1))
t0 = 20/0.005
t1 = 55/0.005
plot (data_solid$time[t0:t1], data_solid$x[t0:t1],type='l', ylim=c(-0.2,0.7), xlab="Temps(s)", ylab="Position(µm)")
lines (data_solid$time[t0:t1],data_solid$x.1[t0:t1])
lines (data_solid$time[t0:t1],data_solid$x.2[t0:t1], col="red")
lines (data_solid$time[t0:t1],data_solid$x.3[t0:t1], col="red")
lines (data_solid$time[t0:t1],data_solid$x[t0:t1]-(data_solid$x[t0:t1]-data_solid$x.1[t0:t1])/2, col = "gray")
lines (data_solid$time[t0:t1],(data_solid$x.2[t0:t1]+data_solid$x.3[t0:t1])/2, col="purple")

plot (data_solid$time[t0:t1],nb_fibres_left_poly[t0:t1], type='l',col="red", ylim=c(0,4))
lines(data_solid$time[t0:t1],nb_fibres_right_poly[t0:t1], col= "blue")
# Out:
# plot without title

# %%
#png("../../../Figures/97MTseuil100KTMT10run_mt.png", width = 1000, height = 1000)
par(mfrow=c(3,1))

plot (data_solid$time,(dist_spb_kt_right-0.15)+0.01, col="black", type = 'l')
lines(data_solid$time,(dist_spb_kt_right-0.15)-0.01, col = "black")
lines(data_solid$time, size_fibres_right_1, col = "pink")
lines(data_solid$time, size_fibres_right_2, col = "purple")
lines(data_solid$time, size_fibres_right_3, col = "green")
lines(data_solid$time, size_fibres_right_4, col = "blue")

plot (data_solid$time,(dist_spb_kt_left-0.15)+0.01, col="black", type = 'l')
lines(data_solid$time,(dist_spb_kt_left-0.15)-0.01, col = "black")
lines(data_solid$time, size_fibres_left_1, col = "pink")
lines(data_solid$time, size_fibres_left_2, col = "purple")
lines(data_solid$time, size_fibres_left_3, col = "green")
lines(data_solid$time, size_fibres_left_4, col = "blue")

plot (data_crosslinker_left$time, data_crosslinker_left$attached.attached, type='l', col ="red")
lines (data_crosslinker_right$time, data_crosslinker_right$attached.attached, type='l', col ="blue")


#dev.off()
# Out:
# Error in plot(data_crosslinker_left$time, data_crosslinker_left$attached.attached, : objet 'data_crosslinker_left' introuvable
# Traceback:
#
# 1. plot(data_crosslinker_left$time, data_crosslinker_left$attached.attached,
#  .     type = "l", col = "red")

# %%
#png("../../../Figures/97MTseuil100KTMT10run_mtdyn.png", width = 1000, height = 500)
par(mfrow=c(2,1))
plot (data_solid$time,(dist_spb_kt_right-0.15)+0.01, col="black", type = 'l', xlim=c(52,57), ylim=c(0.7,0.9) )
lines(data_solid$time,(dist_spb_kt_right-0.15)-0.01, col = "black")
lines(data_solid$time, size_fibres_right_1, col = "pink")
lines(data_solid$time, size_fibres_right_2, col = "purple")
lines(data_solid$time, size_fibres_right_3, col = "green")
lines(data_solid$time, size_fibres_right_4, col = "blue")

plot (data_solid$time,(dist_spb_kt_left-0.15)+0.01, col="black", type = 'l', xlim=c(52,57), ylim=c(0.05,0.25) )
lines(data_solid$time,(dist_spb_kt_left-0.15)-0.01, col = "black")
lines(data_solid$time, size_fibres_left_1, col = "pink")
lines(data_solid$time, size_fibres_left_2, col = "purple")
lines(data_solid$time, size_fibres_left_3, col = "green")
lines(data_solid$time, size_fibres_left_4, col = "blue")
#dev.off()

# %%
#install.packages("plotly")
#library(plotly)

#plot_ly (data_solid, data_solid$time,(dist_spb_kt_right-0.15)+0.01, col="black", type = 'l' )

# %%
#moyenne des longueurs des 4 MT en fonction des 4MT opposé
size_fibres_left = cbind(size_fibres_left_1, size_fibres_left_2)
size_fibres_left = cbind(size_fibres_left, size_fibres_left_3)
size_fibres_left = cbind(size_fibres_left, size_fibres_left_4)
mean_mt_left = rowMeans(size_fibres_left)

size_fibres_right = cbind(size_fibres_right_1, size_fibres_right_2)
size_fibres_right = cbind(size_fibres_right, size_fibres_right_3)
size_fibres_right = cbind(size_fibres_right, size_fibres_right_4)
mean_mt_right = rowMeans(size_fibres_right)

#png("../../../Figures/97MTseuil20KTMT10run_mt_mt.png", width = 1000, height = 500)
plot (mean_mt_left[0:1700],mean_mt_right[0:1700], type = 'l')
#dev.off()

# %%
t1 = 1200
t2 = 1250
par(mfrow=c(4,1))
plot (data_solid$time[t1:t2],mean_mt_left[t1:t2]-mean_mt_left[(t1+1):(t2+1)], type='l')
#lines(data_solid$time[t1:t2],mean_mt_right[t1:t2]-mean_mt_right[(t1+1):(t2+1)], col='red', type='l')
lines(data_solid$time[t1:t2],size_fibres_left_1[t1:t2]-size_fibres_left_1[(t1+1):(t2+1)], col='gray', type='l')
lines(data_solid$time[t1:t2],size_fibres_left_2[t1:t2]-size_fibres_left_2[(t1+1):(t2+1)], col='blue', type='l')
lines(data_solid$time[t1:t2],size_fibres_left_3[t1:t2]-size_fibres_left_3[(t1+1):(t2+1)], col='green', type='l')
lines(data_solid$time[t1:t2],size_fibres_left_4[t1:t2]-size_fibres_left_4[(t1+1):(t2+1)], col='purple', type='l')

plot (data_solid$time[t1:t2],data_solid$x.3[t1:t2]-data_solid$x.2[t1:t2], col="black", type='l')

plot (data_solid$time[t1:t2],data_solid$x.2[t1:t2], col="black", type='l')
lines (data_solid$time[t1:t2],data_solid$x.3[t1:t2], col="red")


plot (data_solid$time[t1:t2], data_ktmt_left$force[t1:t2], col="black", type='l')
lines (data_solid$time[t1:t2],data_ktmt_right$force[t1:t2], col="red")

# %%
par(mfrow=c(2,1))
# Longueur des MT en fonction du temps
plot(data_solid$time, size_fibres_right_1, col = "pink", type = 'l', xlim=c(35,40), ylim = c(0.3,0.38))
lines(data_solid$time, size_fibres_right_2, col = "purple")
lines(data_solid$time, size_fibres_right_3, col = "green")
lines(data_solid$time, size_fibres_right_4, col = "blue")

plot(data_solid$time, size_fibres_left_1, col = "pink", type = 'l', xlim=c(35,40), ylim = c(0.3,0.38))
lines(data_solid$time, size_fibres_left_2, col = "purple")
lines(data_solid$time, size_fibres_left_3, col = "green")
lines(data_solid$time, size_fibres_left_4, col = "blue")
