# %%
import os

os.chdir("/home/sophie/Bureau/simul/")

# %%
for AAAA in (0.0017 , 0.08, 0.16) : 
    for BBBB in (0.0017 , 0.08, 0.16) : 
        for CCC in (5, 75, 150):
            for DDDD in (0.01, 0.5, 1):
                for EEE in (0.5, 12, 25):
                    for FFF in (20,100,200):
                        for GGG in (10, 50, 90):
                            
                            file_name = (str(AAAA)+"00")[2:6] + "_" \
                                      + (str(BBBB)+"00")[2:6] + "_" \
                                      + ("00"+str(CCC))[-3:]  + "_" \
                                      + ((str(DDDD)+"0000").replace('.','')[:4])  + "_" \
                                      + ((str(EEE)+"0").replace('.','0')[:3])  + "_" \
                                      + (("0"+str(FFF))[-3:]) + "_" \
                                      + (("0"+str(GGG))[-3:]) + ".cym"
                                    
                            file = open (file_name, "w")
                            
                            file.write("% Sophie THEIS\n")
                            file.write("% NOTE: parameters use units of picoNewton, micrometer, second\n")
                            file.write("\n")
                            file.write("set simul pombe\n")
                            file.write("{\n")
                            file.write("    time_step  = 0.05\n")
                            file.write("    kT         = 0.0042\n")
                            file.write("    viscosity  = 0.9\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("%% Definition du noyau\n")
                            file.write("set space nucleus\n")
                            file.write("{\n")
                            file.write("    geometry = ( capsule 0 1)\n")
                            file.write("    display = ( color=0xFFFFFF55; )\n")
                            file.write("}\n")
                            file.write("new space nucleus\n")
                            file.write("\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("%% ---------------------------------------------------------------SPB--------------------------------------------------------------- %%\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("% Definition des SPBs\n")
                            file.write("set fiber microtubule_interdigite_spb1\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 22\n")
                            file.write("    segmentation = 0.1\n")
                            file.write("    %total_polymer = 50\n")
                            file.write("\n")
                            file.write("    activity         = classic\n")
                            file.write("    growing_speed    = 0.05, 0.001\n")
                            file.write("    shrinking_speed  = -0.16\n")
                            file.write("    catastrophe_rate = 0.002 , 0.02\n")
                            file.write("    rescue_rate      = 0.05\n")
                            file.write("    growing_force    = 0.01\n")
                            file.write("\n")
                            file.write("    binding_key = 5\n")
                            file.write("    display = {color=light_gray; line_width=0.5}\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("% Definition des SPBs\n")
                            file.write("set fiber microtubule_kinetochore_spb1\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 22\n")
                            file.write("    segmentation = 0.1\n")
                            file.write("\n")
                            file.write("    activity         = classic\n")
                            file.write("    growing_speed    = 0, 0.001\n")
                            file.write("    %shrinking_speed  = -0.16\n")
                            file.write("    shrinking_speed  = -0.09\n")
                            file.write("    catastrophe_rate = 0.005, 0.04\n")
                            file.write("    rescue_rate      = 0.001\n")
                            file.write("    growing_force    = 0.01\n")
                            file.write("\n")
                            file.write("    binding_key = 6\n")
                            file.write("    display = {color=pink; line_width=0.5}\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("set solid spb_corpse1\n")
                            file.write("{\n")
                            file.write("    steric = 1\n")
                            file.write("    confine = surface, 100, nucleus\n")
                            file.write("    display = ( color=light_gray; style=2 )\n")
                            file.write("}\n")
                            file.write("set aster SPB1\n")
                            file.write("{\n")
                            file.write("    solid = spb_corpse1\n")
                            file.write("    nb_fibers_type = 2\n")
                            file.write("    fibers1 = microtubule_interdigite_spb1\n")
                            file.write("    fibers2 = microtubule_kinetochore_spb1\n")
                            file.write("    nucleation_rate = 0.1\n")
                            file.write("    stiffness1 = 1000, 1000\n")
                            file.write("    stiffness2 = 1000, 1\n")
                            file.write("}\n")
                            file.write("new 1 aster SPB1\n")
                            file.write("{\n")
                            file.write("    position = ( -1 0)\n")
                            file.write("    radius = 0.1\n")
                            file.write("\n")
                            file.write("    %microtubule_interdigite\n")
                            file.write("    nb_fibers1 = 25\n")
                            file.write("    length1 = 1.05\n")
                            file.write("    random_position1 = straight_aleatory\n")
                            file.write("    random_direction1 = positive\n")
                            file.write("    random_pos_x1 = 0, 0\n")
                            file.write("    random_pos_y1 = -0.01, 0.01\n")
                            file.write("    random_pos_z1 = 0, 0\n")
                            file.write("\n")
                            file.write("    % microtubule_kinetochore\n")
                            file.write("    nb_fibers2 = 4\n")
                            file.write("    length2 = 0.1\n")
                            file.write("    random_position2 = fan\n")
                            file.write("    angle_start2 = 80\n")
                            file.write("    angle2 = 60\n")
                            file.write("\n")
                            file.write("    orientation = identity\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("set fiber microtubule_interdigite_spb2\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 22\n")
                            file.write("    segmentation = 0.1\n")
                            file.write("    %total_polymer = 50\n")
                            file.write("\n")
                            file.write("    activity         = classic\n")
                            file.write("    growing_speed    = 0.05, 0.001\n")
                            file.write("    shrinking_speed  = -0.16\n")
                            file.write("    catastrophe_rate = 0.002 , 0.02\n")
                            file.write("    rescue_rate      = 0.05\n")
                            file.write("    growing_force    = 0.01\n")
                            file.write("\n")
                            file.write("    binding_key = 7\n")
                            file.write("    display = {color=light_gray; line_width=0.5}\n")
                            file.write("}\n")
                            file.write("set fiber microtubule_kinetochore_spb2\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 22\n")
                            file.write("    segmentation = 0.1\n")
                            file.write("\n")
                            file.write("    activity         = classic\n")
                            file.write("    growing_speed    = 0, 0.001\n")
                            file.write("    %shrinking_speed  = -0.16\n")
                            file.write("    shrinking_speed  = -0.09\n")
                            file.write("    catastrophe_rate = 0.005, 0.04\n")
                            file.write("    rescue_rate      = 0.001\n")
                            file.write("    growing_force    = 0.01\n")
                            file.write("\n")
                            file.write("    binding_key = 8\n")
                            file.write("    display = {color=pink; line_width=0.5}\n")
                            file.write("}\n")
                            file.write("set solid spb_corpse2\n")
                            file.write("{\n")
                            file.write("    steric = 1\n")
                            file.write("    confine = surface, 100, nucleus\n")
                            file.write("    display = ( color=light_gray; style=2 )\n")
                            file.write("}\n")
                            file.write("set aster SPB2\n")
                            file.write("{\n")
                            file.write("    solid = spb_corpse2\n")
                            file.write("    nb_fibers_type = 2\n")
                            file.write("    fibers1 = microtubule_interdigite_spb2\n")
                            file.write("    fibers2 = microtubule_kinetochore_spb2\n")
                            file.write("    nucleation_rate = 0.1\n")
                            file.write("    stiffness1 = 1000, 1000\n")
                            file.write("    stiffness2 = 1000, 1\n")
                            file.write("}\n")
                            file.write("new 1 aster SPB2\n")
                            file.write("{\n")
                            file.write("    position = ( 1 0)\n")
                            file.write("    radius = 0.1\n")
                            file.write("\n")
                            file.write("    %microtubule_interdigite\n")
                            file.write("    nb_fibers1 = 25\n")
                            file.write("    length1 = 1.05\n")
                            file.write("    random_position1 = straight_aleatory\n")
                            file.write("    random_direction1 = negative\n")
                            file.write("    random_pos_x1 = 0, 0\n")
                            file.write("    random_pos_y1 = -0.01, 0.01\n")
                            file.write("    random_pos_z1 = 0, 0\n")
                            file.write("\n")
                            file.write("    % microtubule_kinetochore\n")
                            file.write("    nb_fibers2 = 4\n")
                            file.write("    length2 = 0.1\n")
                            file.write("    random_position2 = fan\n")
                            file.write("    angle_start2 = 100\n")
                            file.write("    angle2 = 60\n")
                            file.write("    orientation = identity\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("%% -----------------------------------------------------------KINETOCHORE----------------------------------------------------------- %%\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("%% Definition des KTs\n")
                            file.write("set fiber kt_fiber_link_left\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 100\n")
                            file.write("    segmentation = 0.5\n")
                            file.write("    display = {color=light_gray; line_width=0.5}\n")
                            file.write("    binding_key = 1\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("set fiber kt_fiber_left\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 100\n")
                            file.write("    segmentation = 0.5\n")
                            file.write("    display = {color=light_gray; line_width=0.5}\n")
                            file.write("    binding_key = 3\n")
                            file.write("}\n")
                            file.write("set solid kt1\n")
                            file.write("{\n")
                            file.write("    steric = 1\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    display = ( color=purple; style=2 )\n")
                            file.write("}\n")
                            file.write("set aster kinetochore_left\n")
                            file.write("{\n")
                            file.write("    solid = kt1\n")
                            file.write("    nb_fibers_type = 2\n")
                            file.write("    fibers1 = kt_fiber_link_left\n")
                            file.write("    fibers2 = kt_fiber_left\n")
                            file.write("    stiffness1 = 1000, 500\n")
                            file.write("    stiffness2 = 1000, 500\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("set fiber kt_fiber_link_right\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 100\n")
                            file.write("    segmentation = 0.5\n")
                            file.write("    display = {color=light_gray; line_width=0.5}\n")
                            file.write("    binding_key = 2\n")
                            file.write("}\n")
                            file.write("set fiber kt_fiber_right\n")
                            file.write("{\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    rigidity = 100\n")
                            file.write("    segmentation = 0.5\n")
                            file.write("    display = {color=light_gray; line_width=0.5}\n")
                            file.write("    binding_key = 4\n")
                            file.write("}\n")
                            file.write("set solid kt2\n")
                            file.write("{\n")
                            file.write("    steric = 1\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    display = ( color=purple; style=2 )\n")
                            file.write("}\n")
                            file.write("set aster kinetochore_right\n")
                            file.write("{\n")
                            file.write("    solid = kt2\n")
                            file.write("    nb_fibers_type = 2\n")
                            file.write("    fibers1 = kt_fiber_link_right\n")
                            file.write("    fibers2 = kt_fiber_right\n")
                            file.write("    stiffness1 = 1000, 500\n")
                            file.write("    stiffness2 = 1000, 500\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("% Definition de la cohesin\n")
                            file.write("set hand binder_kinetochore1\n")
                            file.write("{\n")
                            file.write("    binding_rate = 500\n")
                            file.write("    binding_range = 0.001\n")
                            file.write("    unbinding_rate = 0.0001\n")
                            file.write("    unbinding_force = 5\n")
                            file.write("    binding_key = 1\n")
                            file.write("    display = (color = light_gray)\n")
                            file.write("}\n")
                            file.write("set hand binder_kinetochore2\n")
                            file.write("{\n")
                            file.write("    binding_rate = 500\n")
                            file.write("    binding_range = 0.001\n")
                            file.write("    unbinding_rate = 0.0001\n")
                            file.write("    unbinding_force = 5\n")
                            file.write("    binding_key = 2\n")
                            file.write("    display = (color = light_gray )\n")
                            file.write("}\n")
                            file.write("set couple cohesin\n")
                            file.write("{\n")
                            file.write("    hand1 = binder_kinetochore1\n")
                            file.write("    hand2 = binder_kinetochore2\n")
                            file.write("\n")
                            file.write("    stiffness = "+str(CCC)+"\n")
                            file.write("    diffusion = 0\n")
                            file.write("    fast_diffusion = 0\n")
                            file.write("    length = 0\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("%% Declaration des chromosomes\n")
                            file.write("% CHR1\n")
                            file.write("new 1 aster kinetochore_left\n")
                            file.write("{\n")
                            file.write("    position = ( 0.42 0 )\n")
                            file.write("    radius = 0.075\n")
                            file.write("    % kt_fibers_link\n")
                            file.write("    nb_fibers1 = 2\n")
                            file.write("    length1 = 0.1\n")
                            file.write("    random_position1 = straight\n")
                            file.write("    random_direction1 = positive\n")
                            file.write("    random_pos_x1 = 0, 0\n")
                            file.write("    random_pos_y1 = -0.1, 0.1\n")
                            file.write("    random_pos_z1 = 0, 0\n")
                            file.write("\n")
                            file.write("    %kt_fibers\n")
                            file.write("    nb_fibers2 = 4\n")
                            file.write("    length2 = 0.1\n")
                            file.write("    random_position2 = straight\n")
                            file.write("    random_direction2 = negative\n")
                            file.write("    random_pos_x2 = 0, 0\n")
                            file.write("    random_pos_y2 = -0.035, 0.035\n")
                            file.write("    random_pos_z2 = 0, 0\n")
                            file.write("\n")
                            file.write("    orientation = identity\n")
                            file.write("}\n")
                            file.write("new 1 aster kinetochore_right\n")
                            file.write("{\n")
                            file.write("    position = ( 0.58 0)\n")
                            file.write("    radius = 0.075\n")
                            file.write("    % kt_fibers_link\n")
                            file.write("    nb_fibers1 = 2\n")
                            file.write("    length1 = 0.1\n")
                            file.write("    random_position1 = straight\n")
                            file.write("    random_direction1 = negative\n")
                            file.write("    random_pos_x1 = 0, 0\n")
                            file.write("    random_pos_y1 = -0.1, 0.1\n")
                            file.write("    random_pos_z1 = 0, 0\n")
                            file.write("\n")
                            file.write("    %kt_fibers\n")
                            file.write("    nb_fibers2 = 4\n")
                            file.write("    length2 = 0.1\n")
                            file.write("    random_position2 = straight\n")
                            file.write("    random_direction2 = positive\n")
                            file.write("    random_pos_x2 = 0, 0\n")
                            file.write("    random_pos_y2 = -0.035, 0.035\n")
                            file.write("    random_pos_z2 = 0, 0\n")
                            file.write("    orientation = identity\n")
                            file.write("}\n")
                            file.write("new 2 couple cohesin\n")
                            file.write("{\n")
                            file.write("    position = ( 0.485 0.05 )\n")
                            file.write("    post_translation = ( 0.03 0 0)\n")
                            file.write("}\n")
                            file.write("new 2 couple cohesin\n")
                            file.write("{\n")
                            file.write("    position = ( 0.485 -0.05 )\n")
                            file.write("    post_translation = ( 0.03 0 0)\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("%% -------------------------------------------------------------MOTEURS------------------------------------------------------------- %%\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("\n")
                            file.write("% Definition de ASE1\n")
                            file.write("set hand ase1_bind1\n")
                            file.write("{\n")
                            file.write("    binding_rate = 50\n")
                            file.write("    binding_range = 0.07\n")
                            file.write("    unbinding_rate = 1.8\n")
                            file.write("    unbinding_force = 4\n")
                            file.write("\n")
                            file.write("    binding_key = 5\n")
                            file.write("    display = { color=red; size=1 }\n")
                            file.write("}\n")
                            file.write("set hand ase1_bind2\n")
                            file.write("{\n")
                            file.write("    binding_rate = 50\n")
                            file.write("    binding_range = 0.07\n")
                            file.write("    unbinding_rate = 1.8\n")
                            file.write("    unbinding_force = 4\n")
                            file.write("\n")
                            file.write("    binding_key = 7\n")
                            file.write("    display = { color=red; size=1 }\n")
                            file.write("}\n")
                            file.write("set couple ASE1\n")
                            file.write("{\n")
                            file.write("    hand1 = ase1_bind1\n")
                            file.write("    hand2 = ase1_bind2\n")
                            file.write("\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    stiffness = 50		% Rigidite du lien\n")
                            file.write("    diffusion = 20		% Coefficient de diffusion pour les hands libres\n")
                            file.write("    fast_diffusion = 1\n")
                            file.write("    length = 0		% Longueur du lien au repos\n")
                            file.write("\n")
                            file.write("    activity = crosslink\n")
                            file.write("    specificity = 1 % BIND_ANTIPARALLEL\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("%% COUPLE CONNEXION ENTRE KT ET SPB\n")
                            file.write("\n")
                            file.write("% Definition des couples KTs-MTs\n")
                            file.write("set hand kt_hand1\n")
                            file.write("{\n")
                            file.write("    binding_rate = 50\n")
                            file.write("    binding_range = 0.05\n")
                            file.write("    unbinding_rate = 0.00001\n")
                            file.write("    unbinding_force = 5\n")
                            file.write("\n")
                            file.write("    activity = track\n")
                            file.write("    bind_end = plus_end\n")
                            file.write("    bind_end_range = 0.001\n")
                            file.write("    track_end = plus_end\n")
                            file.write("    bind_only_free_end = 1 %true\n")
                            file.write("\n")
                            file.write("    display = {color = pink; size = 1 }\n")
                            file.write("    binding_key = 3\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("set hand mt_hand1\n")
                            file.write("{\n")
                            file.write("    binding_rate = 50\n")
                            file.write("    binding_range = "+str(DDDD)+"\n")
                            file.write("    unbinding_rate = 0.00001\n")
                            file.write("    unbinding_force = 5\n")
                            file.write("\n")
                            file.write("    hold_shrinking_end = 1 % false\n")
                            file.write("\n")
                            file.write("    activity = track\n")
                            file.write("    bind_end = plus_end\n")
                            file.write("    bind_end_range = 0.01\n")
                            file.write("    track_end = plus_end\n")
                            file.write("    bind_only_free_end = 1 % true\n")
                            file.write("    bind_only_growing_end = 0 %false\n")
                            file.write("\n")
                            file.write("    display = {color = pink; size = 1 }\n")
                            file.write("    binding_key = 6\n")
                            file.write("}\n")
                            file.write("set couple KTMT\n")
                            file.write("{\n")
                            file.write("    hand1 = kt_hand1\n")
                            file.write("    hand2 = mt_hand1\n")
                            file.write("\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    stiffness = "+str(FFF)+" % Rigidite du lien\n")
                            file.write("    diffusion = 0.01		% Coefficient de diffusion pour les hands libres\n")
                            file.write("    fast_diffusion = 0\n")
                            file.write("    length = 0		% Longueur du lien au repos\n")
                            file.write("\n")
                            file.write("    activity = crosslink\n")
                            file.write("    trans_activated = 1\n")
                            file.write("\n")
                            file.write("}\n")
                            file.write("new 40 couple KTMT (rectangle 0.5 0.5 0.5 at 0.38 -0.2 0)\n")
                            file.write("\n")
                            file.write("set hand kt_hand2\n")
                            file.write("{\n")
                            file.write("    binding_rate = 50\n")
                            file.write("    binding_range = 0.05\n")
                            file.write("    unbinding_rate = 0.00001\n")
                            file.write("    unbinding_force = 5\n")
                            file.write("\n")
                            file.write("    activity = track\n")
                            file.write("    bind_end = plus_end\n")
                            file.write("    bind_end_range = 0.001\n")
                            file.write("    track_end = plus_end\n")
                            file.write("    bind_only_free_end = 1 %true\n")
                            file.write("\n")
                            file.write("    display = {color = pink; size = 1 }\n")
                            file.write("    binding_key = 4\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("set hand mt_hand2\n")
                            file.write("{\n")
                            file.write("    binding_rate = 50\n")
                            file.write("    binding_range ="+str(DDDD)+"\n")
                            file.write("    unbinding_rate = 0.00001\n")
                            file.write("    unbinding_force = 5\n")
                            file.write("\n")
                            file.write("    hold_shrinking_end = 1 % false\n")
                            file.write("\n")
                            file.write("    activity = track\n")
                            file.write("    bind_end = plus_end\n")
                            file.write("    bind_end_range = 0.01\n")
                            file.write("    track_end = plus_end\n")
                            file.write("    bind_only_free_end = 1 % true\n")
                            file.write("    bind_only_growing_end = 0 %false\n")
                            file.write("\n")
                            file.write("    display = {color = pink; size = 1 }\n")
                            file.write("    binding_key = 8\n")
                            file.write("}\n")
                            file.write("set couple KTMT2\n")
                            file.write("{\n")
                            file.write("    hand1 = kt_hand2\n")
                            file.write("    hand2 = mt_hand2\n")
                            file.write("\n")
                            file.write("    confine = inside, 100, nucleus\n")
                            file.write("    stiffness = "+str(FFF)+" % Rigidite du lien\n")
                            file.write("    diffusion = 0.01		% Coefficient de diffusion pour les hands libres\n")
                            file.write("    fast_diffusion = 0\n")
                            file.write("    length = 0		% Longueur du lien au repos\n")
                            file.write("\n")
                            file.write("    activity = crosslink\n")
                            file.write("    trans_activated = 1\n")
                            file.write("\n")
                            file.write("}\n")
                            file.write("new 40 couple KTMT2 (rectangle 0.5 0.5 0.5 at 0.24 -0.2 0)\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("new 500 couple ASE1\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("%% -----------------------------------------------------------INTERACTION----------------------------------------------------------- %%\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("\n")
                            file.write("interaction\n")
                            file.write("{\n")
                            file.write("    activity = kinetochore_spb\n")
                            file.write("    nb_chr = 1\n")
                            file.write("    kt1 = kinetochore_left\n")
                            file.write("    kt2 = kinetochore_right\n")
                            file.write("    fiber_kt1_link = kt_fiber_link_left\n")
                            file.write("    fiber_kt2_link = kt_fiber_link_right\n")
                            file.write("    spb1 = SPB1\n")
                            file.write("    spb2 = SPB2\n")
                            file.write("    fiber_spb_to_kt1 = microtubule_kinetochore_spb1\n")
                            file.write("    fiber_spb_to_kt2 = microtubule_kinetochore_spb2\n")
                            file.write("    fiber_kt_to_spb1 = kt_fiber_left\n")
                            file.write("    fiber_kt_to_spb2 = kt_fiber_right\n")
                            file.write("    couple1 = KTMT\n")
                            file.write("    couple2 = KTMT2\n")
                            file.write("    cohesin = cohesin\n")
                            file.write("    nbMTattachedThreshold = 2\n")
                            file.write("    growing_speed_capture=0.09\n")
                            file.write("    shrinking_speed_capture=-0.09\n")
                            file.write("    growing_speed_KTmt_spindle="+str(AAAA)+"\n")
                            file.write("    shrinking_speed_KTmt_spindle=-"+str(BBBB)+"\n")
                            file.write("    metaphase_duration=900\n")
                            file.write("    hinge_position = "+str(GGG)+"\n")
                            file.write("    force_max = "+str(EEE)+"\n")
                            file.write("}\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("%% ---------------------------------------------------------RUN SIMULATION---------------------------------------------------------- %%\n")
                            file.write("%% --------------------------------------------------------------------------------------------------------------------------------- %%\n")
                            file.write("\n")
                            file.write("run simul *\n")
                            file.write("{\n")
                            file.write("    write_object = solid couple:ASE1 couple:cohesin couple:KTMT couple:KTMT2 fiber:microtubule_interdigite_spb1 fiber:microtubule_interdigite_spb2 fiber:microtubule_kinetochore_spb1 fiber:microtubule_kinetochore_spb2\n")
                            file.write("    nb_steps   = 18000\n")
                            file.write("    nb_frames  = 18000\n")
                            file.write("}\n")
                            
                            file.close()
